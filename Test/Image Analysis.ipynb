# %%
#!/usr/bin/env python3

# %%
# Importing the necessary modules 
import matplotlib.pyplot as plt 
import supervision as sv 
import cv2
from ultralytics import YOLO
import torch 
from IPython.display import Image

# %%
# Optional: Check if a GPU is available (recommended for faster training)
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("GPU not found. Training on CPU (will be slower).")

# Load and download the yolo model 
model = YOLO('yolov8s.pt')
# Out:
# GPU not found. Training on CPU (will be slower).

# %%
# Setting the path to the trained model 
bestModelPath = "yolov8s.pt"

# loading the model 
trainedModel = YOLO(bestModelPath)

# %%
# Setting the path to the image 
imagePath = "img.png" 

# Displaying the bandits image
Image(filename=imagePath, width=800)

# %%
image = cv2.imread(imagePath)

# Getting the results 
results = trainedModel(image)[0]

# 
detections = sv.Detections.from_ultralytics(results) 

# 
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()
# Out:
# 0: 448x640 11 persons, 1 backpack, 1 handbag, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
labels = [
    f"{class_name} {confidence:.2f}"
    for class_name, confidence 
    in zip(detections['class_name'], detections.confidence)
]

# %%
detections["class_name"]
# Out:
# array(['person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'backpack', 'handbag', 'person'], dtype='<U8')

# %%
detections.confidence
# Out:
# array([    0.92755,     0.84658,     0.74778,      0.7159,       0.703,     0.64448,     0.55872,     0.44646,     0.40227,     0.35009,      0.3229,     0.32252,      0.2592], dtype=float32)

# %%
for className, confidence in zip(detections["class_name"], detections.confidence): 
    # Checking 
    if (className == "bandits"): 
        print(f"Bandits Detected! with a percentage accuracy of {confidence * 100}") 
        
    print(className, confidence)
# Out:
# person 0.9275512
# person 0.84657854
# person 0.7477825
# person 0.7159025
# person 0.70300436
# person 0.6444773
# person 0.5587235
# person 0.446463
# person 0.40227214
# person 0.3500898
# backpack 0.32290155
# handbag 0.32252076
# person 0.2591994

# %%
annotated_image = box_annotator.annotate(
    scene=image, detections=detections)

annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections, labels=labels)

# %%
cv2.imwrite("annotatedImage.jpg", annotated_image)
# Out:
# True

# %%
labels
# Out:
# ['person 0.93',
#  'person 0.85',
#  'person 0.75',
#  'person 0.72',
#  'person 0.70',
#  'person 0.64',
#  'person 0.56',
#  'person 0.45',
#  'person 0.40',
#  'person 0.35',
#  'backpack 0.32',
#  'handbag 0.32',
#  'person 0.26']

# %%
# Setting the path to the image 
imagePath = "annotatedImage.jpg" 

# Displaying the bandits image
Image(filename=imagePath, width=800)

# %%
# Box annotation 
image = cv2.imread(imagePath)

# Getting the results 
results = trainedModel(image)[0]

# 
detections = sv.Detections.from_ultralytics(results) 

# 
corner_annotator = sv.BoxCornerAnnotator() 
annotated_frame = corner_annotator.annotate(
    scene=image.copy(), 
    detections=detections
)

annotated_frame = label_annotator.annotate(
    scene=annotated_frame, detections=detections, labels=labels)
# Out:
# 0: 448x640 7 persons, 110.5ms
# Speed: 6.8ms preprocess, 110.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 17
#      11 corner_annotator = sv.BoxCornerAnnotator()
#      12 annotated_frame = corner_annotator.annotate(
#      13     scene=image.copy(),
#      14     detections=detections
#      15 )
# ---> 17 annotated_frame = label_annotator.annotate(
#      18     scene=annotated_frame, detections=detections, labels=labels)
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/supervision/utils/conversion.py:23, in ensure_cv2_image_for_class_method.<locals>.wrapper(self, scene, *args, **kwargs)
#      20 @wraps(annotate_func)
#      21 def wrapper(self, scene: ImageType, *args, **kwargs):
#      22     if isinstance(scene, np.ndarray):
# ---> 23         return annotate_func(self, scene, *args, **kwargs)
#      25     if isinstance(scene, Image.Image):
#      26         scene_np = pillow_to_cv2(scene)
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/supervision/annotators/core.py:1181, in LabelAnnotator.annotate(self, scene, detections, labels, custom_color_lookup)
#    1140 """
#    1141 Annotates the given scene with labels based on the provided detections.
#    1142
#    (...)
#    1178 supervision-annotator-examples/label-annotator-example-purple.png)
#    1179 """
#    1180 assert isinstance(scene, np.ndarray)
# -> 1181 validate_labels(labels, detections)
#    1183 labels = get_labels_text(detections, labels)
#    1184 label_properties = self._get_label_properties(detections, labels)
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/supervision/annotators/utils.py:215, in validate_labels(labels, detections)
#     202 """
#     203 Validates that the number of provided labels matches the number of detections.
#     204
#    (...)
#     212     of detections.
#     213 """
#     214 if labels is not None and len(labels) != len(detections):
# --> 215     raise ValueError(
#     216         f"The number of labels ({len(labels)}) does not match the "
#     217         f"number of detections ({len(detections)}). Each detection "
#     218         f"should have exactly 1 label."
#     219     )
#
# ValueError: The number of labels (13) does not match the number of detections (7). Each detection should have exactly 1 label.

# %%
cv2.imwrite("boxImage.jpg", annotated_frame)

# Displaying the bandits image
Image(filename="boxImage.jpg", width=800)

# %%
# Predict the image 
results = trainedModel(imagePath)

# Extract boxes, confidences, and class IDs from first image result
boundingBoxes = results[0].boxes.xyxy.cpu().numpy()       # Bounding boxes in [x1, y1, x2, y2] format
confidenceScores = results[0].boxes.conf.cpu().numpy()    # Confidence scores
classIds = results[0].boxes.cls.cpu().numpy()             # Class indices

# Optional: class names
classNames = trainedModel.names  # Automatically gets class names from model

# Load original image using OpenCV
originalImage = cv2.imread(imagePath)

# Draw boxes manually
for box, score, classId in zip(boundingBoxes, confidenceScores, classIds):
    x1, y1, x2, y2 = map(int, box)
    label = f"{classNames[int(classId)]}: {score:.2f}"
    print(label)

    # cv2.rectangle(originalImage, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.rectangle(originalImage, (x1, y1), (x2, y2), (0, 255, 0), 1, lineType=cv2.LINE_AA)
    cv2.putText(originalImage, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX,
                0.5, (255, 255, 255), 2)

# # Convert BGR (OpenCV) to RGB (matplotlib)
# imageRgb = cv2.cvtColor(originalImage, cv2.COLOR_BGR2RGB)

# # Display using matplotlib
# plt.figure(figsize=(10, 8))
# plt.imshow(imageRgb)
# plt.axis('off')
# plt.title("YOLOv8 Detection Result")
# plt.show()

# Save the image 
cv2.imwrite("analyzedImage.jpg", originalImage)
# Out:
# image 1/1 /Users/mbonuchinedu/Documents/Projects/banditsProject/Test/annotatedImage.jpg: 320x640 2 banditss, 1 gun, 1 unknown, 204.8ms
# Speed: 1.1ms preprocess, 204.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# bandits: 0.95
# bandits: 0.95
# unknown: 0.93
# gun: 0.93
# True

# %%
# Setting the path to the image 
imagePath = "analyzedImage.jpg" 

# Displaying the bandits image
Image(filename=imagePath, width=800)

# %% [markdown]
# <h2> Simulating Night Vision Imagery </h2>

# %%
# Importing the necessary modules 
import cv2 
import numpy as np 

# Creating the night vision function 
def simulateNightVision(imagePath): 
    # loading the image into memory 
    image = cv2.imread(imagePath) 

    # if the image is none 
    if image is None: 
        # Display an error message 
        print("Error: Could not read the image.")
        return 

    # Convert to gray scale 
    grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply a green color map 
    nightVisionImage = cv2.applyColorMap(grayImage, cv2.COLORMAP_JET) 

    # Enhance constrast and brightness 
    alpha = 1.5 
    beta = 50 
    nightVisionImage = cv2.convertScaleAbs(nightVisionImage, alpha=alpha, beta=beta) 

    # Display the image 
    cv2.imshow("Orignal", image) 
    cv2.imshow("Simulated Night Vision", nightVisionImage) 
    cv2.imshow("Gray Imag", grayImage) 
    cv2.waitKey(0) 
    cv2.destroyAllWindows()

# %%
# Setting the path to the image 
imagePath = "images/train/img15.jpg"

# loading the image 
simulateNightVision(imagePath)
