# %%
#!/usr/bin/env python3

# %%
# Importing the necesary modules 
import cv2 
from google import genai 
import matplotlib.pyplot as plt 
from google.genai import types

# %%
# Setting the path to the image 
imagePath = "image.jpg" 

# loading the image 
image = cv2.imread(imagePath) 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Loading the image into memeory 
with open("image.jpg", "rb") as imageFile: 
    content = imageFile.read()

# %%
# Getting the client 
client = genai.Client(api_key="AIzaSyA_xb5jBScKbeBzJU9XcuNijd9Nl2_Sk-o")

# %%
# Getting the response 
response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents=[
        types.Part.from_bytes(
            data=content,
            mime_type="image/jpeg"
        ),
        """Tell me briefly what you see in this image, 
        assuming the persons are bandits, where are they headed, what are they doing, how many they are, 
        and if they are carrying weapons, what kind of weapons are they carrying?
        Additionnaly, tell me the location of where this image was taken from, and tell me if they are mobile or stationary"""
        # "Tell me in details what you see in this image, assuming the persons are bandits, where are they headed and what are they doing. "
    ]
)

# %%
# Displaying the image 
plt.figure(figsize=(10, 6))
plt.imshow(image) 
plt.show()

# %%
# Displaying the response 
print(response.text)
# Out:
# Here's an analysis of the image based on your prompt:
#
# *   **What you see:** The image shows two individuals, likely men, dressed in traditional desert attire, including turbans/head wraps that obscure most of their faces. Both are armed with assault rifles. A green and white flag is visible in the background on the left.
# *   **Assuming the persons are bandits:**
#     *   **How many they are:** At least **two** individuals are visible. There could be more off-camera.
#     *   **What kind of weapons:** They are carrying **Kalashnikov-pattern assault rifles** (AK-47 or AKM variants), identifiable by their distinct magazine shape and general design.
#     *   **What are they doing:** They appear to be **on guard, patrolling, or presenting an armed front**. Their posture suggests readiness.
# ...
